# %%
    us_path = "../data/raw/USvideos.csv"
    trends_out_path = "../data/raw/google_trends_category.csv"

    if not os.path.exists(us_path):
        raise FileNotFoundError(f"USvideos.csv not found at {us_path}. Please download from Kaggle and place it there.")

    build_category_trends(us_path, trends_out_path)
# Out:
# Saved category trends to ../data/raw/google_trends_category.csv

# %%
    trends_df = pd.read_csv("../data/raw/google_trends_category.csv")
    trends_df.head()
# Out:
#          date  category_id           keyword  trend_score
# 0  2017-11-14            1  film & animation            0
# 1  2017-11-15            1  film & animation            0
# 2  2017-11-16            1  film & animation            0
# 3  2017-11-17            1  film & animation            0
# 4  2017-11-18            1  film & animation            0
